# %%
# ruff: noqa: N802, N803, N806, N815, N816


from archimedes.experimental.approximation import (
    OrthogonalPolynomialBasis,
)
from archimedes.measure import LegendreMeasure
from archimedes.quadrature import gauss_lobatto

# %%
n = 2
quad_rule = gauss_lobatto(n=n)
el_basis = OrthogonalPolynomialBasis(
    measure=LegendreMeasure(),
    n_basis=n,
)

el_basis._derivative_basis(deriv=1)
# Out:
# OrthogonalPolynomialBasis(measure=<archimedes.measure._legendre.LegendreMeasure object at 0x11230ed80>, n_basis=1, density=False)
